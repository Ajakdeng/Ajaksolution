# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajakdeng/Ajaksolution/blob/main/Customer_churn_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0045102e-334f-4023-9895-4ec4f9b330fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0045102e-334f-4023-9895-4ec4f9b330fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# To show show statistics
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# to get customer churn count
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# visualisation of the customer churn
palette = {'Yes': 'blue', 'No': 'red'}
# Count plot for the 'Churn' column with a custom palette
sns.countplot(x='Churn', hue='Churn', data=df,palette=palette , legend=False)
plt.title('Count of Churned Customers')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

# %%
# To see the percentage of customers leaving
numRetained = df[df.Churn == 'No'].shape[0]
numChurned = df[df.Churn == 'Yes'].shape[0]

# print the percentage of customers that stayed
print(numRetained/(numRetained + numChurned) * 100,'% of customers stayed in the company')
# peint the percentage of customers that left
print(numChurned/(numRetained + numChurned) * 100, '% of customers left with the company')
# Out:
# 73.4630129206304 % of customers stayed in the company
# 26.536987079369588 % of customers left with the company

# %%
# Count plot for the 'Churn' column with a custom palette
palette = {'Yes': 'blue', 'No': 'red'}
sns.countplot(x='gender', hue='Churn', data=df, palette=palette)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# visualize the churn count for internet services:
palette = {'Yes': 'blue', 'No': 'red'}
sns.countplot(x='InternetService', hue='Churn', data=df, palette=palette)
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
# Visualizing numeric data
numericFeatures = ['tenure', 'MonthlyCharges']
fig, ax = plt.subplots(1,2, figsize=(28, 8))
df[df.Churn == "No"][numericFeatures].hist(bins=20, color='blue', alpha=0.5, ax=ax)
df[df.Churn == "Yes"][numericFeatures].hist(bins=20, color='orange', alpha=0.5, ax=ax)
# Out:
# array([<Axes: title={'center': 'tenure'}>,
#        <Axes: title={'center': 'MonthlyCharges'}>], dtype=object)

# %%
# remove unnecessary columns
cleanDF = df.drop('customerID', axis=1)

# %%
# convert all non numeric columns to numeric

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Assuming cleanDF is already defined
for column in cleanDF.columns:
    if pd.api.types.is_numeric_dtype(cleanDF[column]):
        continue  # Skip numeric columns
    cleanDF[column] = LabelEncoder().fit_transform(cleanDF[column])

# %%
# to show data types
cleanDF.dtypes
# Out:
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService       int64
# OnlineSecurity        int64
# OnlineBackup          int64
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract              int64
# PaperlessBilling      int64
# PaymentMethod         int64
# MonthlyCharges      float64
# TotalCharges          int64
# Churn                 int64
# dtype: object

# %%
# scale the data
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
x = cleanDF.drop('Churn', axis=1)
y = cleanDF['Churn']
x = StandardScaler().fit_transform(x)

# %%
# split the data into 80% training and 20% testing
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# create and train the model
model = LogisticRegression()
# Train the model
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
# create the prediction on test data
predictions = model.predict(xtest)
# print the predictions
print(predictions)
# Out:
# [1 0 0 ... 0 0 0]

# %%
# check the prediction score:
print(classification_report(ytest, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      1036
#            1       0.69      0.56      0.62       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.74      0.75      1409
# weighted avg       0.81      0.82      0.81      1409
